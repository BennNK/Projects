# %%
from google.colab import drive

drive.mount('/content/drive')

CURR_DIR = "/content/drive/My Drive/Grad School Fall/CS 573/Project/colab_notebooks"
DATA_FILE = "profiles.csv"
NP_DATA_FILE = "parsed.npz"
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
from scipy import sparse

# %%
# data = np.load(os.path.join(CURR_DIR,NP_DATA_FILE))
data = sparse.load_npz(os.path.join(CURR_DIR,NP_DATA_FILE))
np_data = data.toarray()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print(data['data'].shape)
# Out:
# (4145651,)
